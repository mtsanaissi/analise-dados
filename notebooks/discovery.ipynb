# %%
import sys
import os
from main.orchestrator import main
# --- Configuração da Execução ---
# Garante que o diretório raiz do projeto esteja no path
# para que 'src' possa ser encontrado.
# (Pode não ser necessário dependendo de como o VS Code lança o kernel,
# mas é uma boa prática para garantir a robustez)
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

# Armazena os argumentos originais da linha de comando
original_argv = sys.argv

# Define os argumentos para esta execução específica
# O primeiro elemento é tradicionalmente o nome do script
sys.argv = [
    'src/run.py',
    '-d', '../data/sample',
    '-p', 'discovery',
    '--output-format', 'interactive',
    '--compare-fields'
]

try:
    # Chama a função principal que agora irá
    # renderizar os resultados diretamente na sua janela
    main()
finally:
    # Restaura os argumentos originais (importante para
    # não afetar outras células do notebook)
    sys.argv = original_argv
# Out:
# Processando arquivo: d:\w\analise-dados\data\sample\consumidorgovbr_2025-01.csv
# Resultado do cabeçalho: {'error': 'Erro no conector: Error tokenizing data. C error: Expected 4 fields in line 4, saw 5\n'}
# Relatório do arquivo (Erro): {'file': 'consumidorgovbr_2025-01.csv', 'status': 'Erro', 'details': {'error_message': 'Erro no conector: Error tokenizing data. C error: Expected 4 fields in line 4, saw 5\n'}}
# Processando arquivo: d:\w\analise-dados\data\sample\consumidorgovbr_2025-02.csv
# Resultado do cabeçalho: {'error': 'Erro no conector: Error tokenizing data. C error: Expected 5 fields in line 23, saw 8\n'}
# Relatório do arquivo (Erro): {'file': 'consumidorgovbr_2025-02.csv', 'status': 'Erro', 'details': {'error_message': 'Erro no conector: Error tokenizing data. C error: Expected 5 fields in line 23, saw 8\n'}}
# <h2>Análise de Integridade e Estrutura</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Arquivo</th>
#       <th>Tipo</th>
#       <th>Nº de Colunas</th>
#       <th>Status Geral</th>
#       <th>Vazio?</th>
#       <th>Caracteres Problemáticos?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>consumidorgovbr_2025-01.csv</td>
#       <td>CSV</td>
#       <td>19</td>
#       <td>OK</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>consumidorgovbr_2025-02.csv</td>
#       <td>CSV</td>
#       <td>19</td>
#       <td>OK</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Análise de Arquivos CSV</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Arquivo</th>
#       <th>Delimitador Detectado</th>
#       <th>Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>consumidorgovbr_2025-01.csv</td>
#       <td>;</td>
#       <td>N/A</td>
#     </tr>
#     <tr>
#       <td>consumidorgovbr_2025-02.csv</td>
#       <td>;</td>
#       <td>N/A</td>
#     </tr>
#   </tbody>
# </table>
# <h3>Consistência de Colunas (CSV)</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Arquivo</th>
#       <th>Status</th>
#       <th>Mensagem</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>consumidorgovbr_2025-01.csv</td>
#       <td>Erro</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>consumidorgovbr_2025-02.csv</td>
#       <td>Erro</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <h2>Análise de Comparação de Campos</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>file</th>
#       <th>status</th>
#       <th>missing_columns</th>
#       <th>extra_columns</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>consumidorgovbr_2025-01.csv</td>
#       <td>referencia</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>consumidorgovbr_2025-02.csv</td>
#       <td>igual</td>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>
