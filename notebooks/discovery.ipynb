# %%
from src.run import main

# Executa a CLI como módulo, sem alterar sys.path nem sys.argv do kernel.
main([
    'discovery',
    '--data-project-path', '../data/sample',
    '--output-format', 'interactive',
    '--compare-fields'
])
